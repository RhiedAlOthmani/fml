# %%
import seaborn as sns #this is the plotting library I'll be using 
import pandas as pd #"as pd" means that we can use the abbreviation in commands
import matplotlib.pyplot as plt #we need Matplotlib for setting the labels in the Seaborn graphs

steps = pd.read_csv("Assignment 1 - steps data.csv", delimiter = ";")
survey = pd.read_csv('Assignment 1 - survey data.csv')
steps.head(5)
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN        NaN        NaN
# 1   2        NaN        NaN        NaN        NaN        NaN      641.0
# 2   3        NaN        NaN        NaN        NaN        NaN        NaN
# 3   4        NaN        NaN       25.0     4067.0     7192.0      154.0
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  \
# 0        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 1     4045.0     2310.0     2480.0  ...       NaN       NaN       NaN
# 2        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 3     8674.0     8275.0      850.0  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    7-5-2014  8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# 0       NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 1       NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 2       NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 3       NaN       NaN       NaN        NaN        NaN        NaN        NaN
# 4       NaN       NaN       NaN        NaN        NaN        NaN        NaN
#
# [5 rows x 329 columns]

# %%
df = pd.merge(steps, survey, on = 'id') #'id' is the common identifier
df.head(50)
# Out:
#     id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0    1        NaN        NaN        NaN        NaN        NaN        NaN
# 1    2        NaN        NaN        NaN        NaN        NaN      641.0
# 2    3        NaN        NaN        NaN        NaN        NaN        NaN
# 3    4        NaN        NaN       25.0     4067.0     7192.0      154.0
# 4    5        NaN        NaN        NaN        NaN        NaN        NaN
# 5    6        NaN        NaN        NaN        NaN        NaN        NaN
# 6    7        NaN        NaN        NaN        NaN        NaN        NaN
# 7    8        NaN        NaN        NaN        NaN        NaN        NaN
# 8    9        NaN        NaN        NaN        NaN        NaN        NaN
# 9   10        NaN        NaN        NaN        NaN        NaN        NaN
# 10  11        NaN        NaN        NaN        NaN        NaN        NaN
# 11  12        NaN        NaN        NaN        NaN        NaN        NaN
# 12  13        NaN        NaN        NaN        NaN        NaN        NaN
# 13  14        NaN        NaN        NaN        NaN        NaN        NaN
# 14  15        NaN        NaN        NaN        NaN        NaN        NaN
# 15  16     2898.0     8108.0     3478.0     3740.0     2957.0     2164.0
# 16  17        NaN        NaN        NaN        NaN      108.0     4823.0
# 17  18       20.0    16924.0    18357.0    24613.0     1157.0    34381.0
# 18  19        NaN        NaN        NaN        NaN        NaN        NaN
# 19  20        NaN      112.0     8251.0     6290.0    12045.0    11020.0
# 20  21        NaN        NaN        NaN        NaN        NaN        NaN
# 21  22        NaN        NaN        NaN        NaN        NaN     3194.0
# 22  23        NaN    17131.0    16267.0     7009.0     8386.0    10891.0
# 23  24        NaN        NaN        NaN        NaN        NaN        NaN
# 24  25        NaN     2213.0     8958.0     6302.0     4988.0     7616.0
# 25  26        NaN        NaN        NaN        NaN        NaN        NaN
# 26  27        NaN    10381.0    14467.0    10212.0     9456.0     5673.0
# 27  28        NaN    14070.0    20490.0     4700.0        NaN      804.0
# 28  29        NaN        NaN        NaN        NaN        NaN        NaN
# 29  30        NaN     8072.0    25307.0    17925.0    11185.0        NaN
# 30  31        NaN     9465.0    16329.0     7567.0    10949.0     9781.0
# 31  32        NaN        NaN        NaN        NaN        NaN        NaN
# 32  33        NaN     4306.0     8090.0    14968.0     8470.0     9442.0
# 33  34        NaN        NaN        NaN        NaN        NaN        NaN
# 34  35        NaN     6920.0     9699.0     7658.0     6959.0    10200.0
# 35  36        NaN        NaN        NaN        NaN        NaN        NaN
# 36  37      164.0     4637.0     3956.0     4284.0     8716.0    13639.0
# 37  38        NaN        NaN        NaN        NaN        NaN        NaN
# 38  39        NaN    23656.0    10263.0     2553.0        NaN     9025.0
# 39  40        NaN        NaN        NaN        NaN     5481.0    17240.0
# 40  41      358.0     8587.0    16343.0     9281.0    17958.0     7993.0
# 41  42        NaN        NaN        NaN        NaN        NaN        NaN
# 42  43        NaN        NaN        NaN        NaN        NaN        NaN
# 43  44        NaN     5616.0     7653.0      659.0     4801.0      263.0
# 44  45        NaN        NaN      154.0     1623.0     4367.0     6135.0
# 45  46        NaN        NaN        NaN        NaN        NaN        NaN
# 46  47        NaN        NaN        NaN        NaN        NaN        NaN
# 47  48        NaN        NaN        NaN        NaN        NaN        NaN
# 48  49        NaN        NaN        NaN        NaN        NaN        NaN
# 49  50        NaN        NaN        NaN        NaN        NaN        NaN
#
#     26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014         city  gender  \
# 0         NaN        NaN        NaN  ...        NaN  Montpellier    male
# 1      4045.0     2310.0     2480.0  ...        NaN  Montpellier  female
# 2         NaN        NaN        NaN  ...        NaN         Lyon  female
# 3      8674.0     8275.0      850.0  ...        NaN         Lyon    male
# 4         NaN        NaN        NaN  ...        NaN     Bordeaux    male
# 5         NaN        NaN        NaN  ...        NaN         Lyon    male
# 6         NaN        NaN        NaN  ...        NaN     Bordeaux  female
# 7         NaN        NaN        NaN  ...        NaN         Lyon  female
# 8         NaN        NaN        NaN  ...        NaN     Bordeaux  female
# 9         NaN        NaN        NaN  ...        NaN         Lyon  female
# 10        NaN        NaN        NaN  ...        NaN         Lyon    male
# 11        NaN        NaN        NaN  ...        NaN         Lyon  female
# 12        NaN        NaN        NaN  ...        NaN         Lyon  female
# 13        NaN        NaN        NaN  ...        NaN         Lyon  female
# 14        NaN        NaN        NaN  ...        NaN         Lyon  female
# 15       15.0     3434.0     7614.0  ...        NaN         Lyon    male
# 16     2413.0    14412.0    13256.0  ...        NaN     Bordeaux    male
# 17    12722.0        NaN      976.0  ...        NaN        Lille  female
# 18        NaN        NaN        NaN  ...        NaN         Lyon    male
# 19    11247.0    11646.0     6997.0  ...        NaN         Lyon  female
# 20        NaN        NaN     5263.0  ...        NaN         Lyon    male
# 21     9175.0     8728.0    10580.0  ...        NaN         Lyon    male
# 22    12935.0     5551.0    10260.0  ...        NaN        Lille    male
# 23        NaN        NaN        NaN  ...        NaN        Lille    male
# 24    14892.0     5850.0     5529.0  ...        NaN         Lyon    male
# 25        NaN        NaN        NaN  ...        NaN         Lyon    male
# 26     8032.0    11933.0    12748.0  ...        NaN        Lille  female
# 27     6091.0     3182.0     2062.0  ...        NaN         Lyon    male
# 28        NaN        NaN     7129.0  ...        NaN        Lille    male
# 29     7534.0     7222.0     3354.0  ...        NaN         Lyon    male
# 30     3873.0     6763.0     9645.0  ...        NaN         Lyon    male
# 31        NaN        NaN        NaN  ...        NaN         Lyon  female
# 32     7274.0     5934.0     9552.0  ...        NaN         Lyon  female
# 33        NaN        NaN        NaN  ...        NaN  Montpellier    male
# 34     7773.0     7095.0    12825.0  ...        NaN         Lyon    male
# 35        NaN        NaN        NaN  ...        NaN         Lyon    male
# 36    12175.0    12025.0     8936.0  ...        NaN         Lyon    male
# 37        NaN        NaN     8725.0  ...        NaN  Montpellier  female
# 38     9557.0    12048.0    11325.0  ...        NaN         Lyon  female
# 39     6819.0     4042.0    11757.0  ...        NaN         Lyon    male
# 40     9428.0     9778.0     9590.0  ...        NaN        Lille    male
# 41        NaN       15.0    21435.0  ...        NaN  Montpellier    male
# 42        NaN        NaN        NaN  ...        NaN         Lyon  female
# 43        NaN       97.0     6047.0  ...        NaN  Montpellier  female
# 44     5607.0     3926.0     5934.0  ...        NaN         Lyon  female
# 45        NaN        NaN        NaN  ...        NaN         Lyon    male
# 46        NaN        NaN        NaN  ...        NaN     Bordeaux    male
# 47        NaN        NaN        NaN  ...        NaN         Lyon    male
# 48        NaN        NaN    10050.0  ...        NaN         Lyon    male
# 49        NaN        NaN        NaN  ...        NaN         Lyon  female
#
#       age  hh_size        hh_type            education  height  weight  waist
# 0   25-34        2         couple  master or doctorate   183.0    62.0   78.0
# 1   25-34        2         couple          high school   163.0    60.0   75.0
# 2   25-34        2         couple  master or doctorate   172.0    65.0   60.0
# 3   25-34        3  single parent             bachelor   182.0    85.0   95.0
# 4   25-34        2         couple  master or doctorate   177.0    70.0   81.0
# 5   45-54        1         single             bachelor   180.0    81.0   98.0
# 6   25-34        1         single  master or doctorate   160.0    62.0   79.0
# 7   35-44        3  single parent             bachelor   153.0    40.0   60.0
# 8   25-34        3         family  master or doctorate   175.0    71.0   85.0
# 9   25-34        3         family          high school   165.0    68.0   92.0
# 10  55-64        2  single parent             bachelor   175.0    82.0   96.0
# 11  25-34        1         single  master or doctorate   165.0    60.0   73.0
# 12  45-54        3  single parent           vocational   160.0    77.0  107.0
# 13  55-64        1         single  master or doctorate   160.0    64.0   82.0
# 14  45-54        5         family          high school   176.0    96.0  103.0
# 15  55-64        1         single           vocational   173.0    81.0  104.0
# 16  25-34        2         couple  master or doctorate   180.0    70.0   80.0
# 17    <25        3         couple             bachelor   165.0    58.0   80.0
# 18  45-54        2         couple           vocational   178.0    60.0   78.0
# 19  45-54        1         single          high school   168.0    72.0   90.0
# 20  25-34        2         couple             bachelor   172.0    74.0   97.0
# 21  25-34        1         single  master or doctorate   183.0    75.0   87.0
# 22  25-34        2          other          high school   175.0    58.0   76.0
# 23    <25        2          other             bachelor   176.0    70.0   60.0
# 24  35-44        3         family  master or doctorate   179.0    78.0   97.0
# 25  35-44        4         family             bachelor   180.0    88.0  102.0
# 26  25-34        1         single  master or doctorate   163.0    56.0   85.0
# 27  25-34        1         single  master or doctorate   181.0    69.0   83.0
# 28  25-34        2         couple  master or doctorate   173.0    70.0   82.0
# 29  25-34        1         single  master or doctorate   187.0    93.0  106.0
# 30  35-44        4         family  master or doctorate   179.0    76.0   91.0
# 31  25-34        4         family          high school   170.0    63.0   85.0
# 32  25-34        2         couple  master or doctorate   165.0    54.0   73.0
# 33  35-44        3         family          high school   165.0    72.0   92.0
# 34  35-44        4         family             bachelor   170.0    68.0   89.0
# 35  25-34        2         couple             bachelor   180.0    73.0   92.0
# 36  25-34        3         family  master or doctorate   181.0    95.0   99.0
# 37  55-64        3         family             bachelor   155.0    45.0   75.0
# 38  35-44        1         single             bachelor   163.0    53.0   76.0
# 39  25-34        2         couple  master or doctorate   175.0    71.0   85.0
# 40  35-44        5         family             bachelor   173.0    96.0  106.0
# 41  45-54        1         couple              primary   170.0    67.0   82.0
# 42  25-34        1         single  master or doctorate   165.0    61.0   83.0
# 43  25-34        1         single             bachelor   170.0    76.0   87.0
# 44  25-34        2         couple             bachelor   169.0    62.0   78.0
# 45  45-54        4         family  master or doctorate   170.0    61.0   80.0
# 46  25-34        3         family             bachelor   170.0    77.0   87.0
# 47  35-44        2         couple             bachelor   172.0    76.0   90.0
# 48  25-34        2         couple  master or doctorate   174.0    79.0  101.0
# 49  35-44        4         family             bachelor   172.0    78.0   39.0
#
# [50 rows x 338 columns]

# %%
df.info() #Get information on the variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 928
# Columns: 338 entries, id to waist
# dtypes: float64(331), int64(2), object(5)
# memory usage: 2.4+ MB

# %%
df["height"].mean() # get one column, make a new df with a new column
# Out:
# 171.7545945945946

# %%
df["waist"].value_counts() # get the mean per steps
# Out:
# 90.0     46
# 80.0     46
# 84.0     35
# 83.0     32
# 82.0     30
#          ..
# 131.0     1
# 36.0      1
# 39.0      1
# 35.0      1
# 147.0     1
# Name: waist, Length: 85, dtype: int64

# %%
sns.distplot(df['waist'].dropna(), kde=False) #Selecting the rating column. I need to drop the NA's for the plot
plt.title('Waist of ids')
plt.xlabel('Waist (cm)')
plt.show()

# %%
# see the outlines, there is bump and there are weird values on the ends

# %%
# The handy Pandas function to_numeric converts non-numeric data to NaN. The last argument overrides the errors
# Python would normally generate.
# The apply method of a dataframe lets us apply a function to all the elements.
#df['rating'] = df['rating'].apply(pd.to_numeric, errors='coerce')

#To remove the values below 50 we need to create a function that we then apply to the entire column
def below_50(x):
    if(x < 50): 
        return float('NaN')
    else: 
        return x
df['waist'] = df['waist'].apply(below_50)

# %%
sns.distplot(df['waist'].dropna(), kde=False) #Selecting the rating column. I need to drop the NA's for the plot
plt.title('Waist of ids')
plt.xlabel('Waist (cm)')
plt.show()

# %%
df["height"].mean() # get one column, make a new df with a new column
# Out:
# 171.7545945945946

# %%
sns.boxplot(df["height"])
plt.title('height of ids')
plt.xlabel('height in cm')
plt.show()

# %%
# the boxplot shows that the box leans more to the 150cm because there are few people who are shorter

# %%
df["height"].name = 'height' #Labeling the variable for plotting
height_av = df["height"].dropna() #Selecting the size column. I need to drop the NA's, otherwise Seaborn won't plot
sns.distplot(instragram, kde=False) 
plt.title('height')
plt.show()

# %%
mean_size = df["height"].mean()
median_size = df["height"].median()

print(f'The median of height is: {median_size} cm')
print(f'The mean of height is: {mean_size} cm')

sns.distplot(height_av, kde=False)
plt.title('Height of id')
plt.axvline(median_size, 0, 100, color='green', label='median') #This adds a vertical line at x-position median_size, from y = 0 to y = 100 
plt.axvline(mean_size, 0, 100, color='blue', label='mean') 
plt.legend() #This adds a legend. It works automatically because I've set the labels in the previous lines
plt.show()
# Out:
# The median of height is: 172.0 cm
# The mean of height is: 171.7545945945946 cm

# %%
# the mean and median are very close to each other
# there is probably a diffrence between men and when, thats the gap between the bins
